# %%
import pandas as pd
file1 = pd.read_spss("../data/Annual 2005-2011_START.sav")
file1
# Out:
#       Cреднеспис.числ.работн        k1        k2        k3        k4  \
# 0                     6095.0  0.942380  0.060563  0.678302 -0.161531
# 1                      255.0  1.980494  0.274382  0.916775  0.624425
# 2                      114.0  0.374160  0.001494  0.085138 -1.504990
# 3                      365.0  7.859079  0.831978  2.449864  0.875862
# 4                      168.0  1.779376  0.005596  0.883293  0.527853
# ...                      ...       ...       ...       ...       ...
# 2690                   217.0  2.292818  0.157246  1.344241  0.488230
# 2691                   105.0  1.572188  0.163862  1.032772  0.283944
# 2692                   121.0  1.453574  0.023380  0.692051  0.312040
# 2693                   243.0  1.310646  0.014829  0.330798  0.044386
# 2694                    98.0  3.392065  0.320780  1.399462  0.705194
#
#         k4_new        k5        k6        k7        k8  ...       k12  \
# ...

# %%
new_file = file1.dropna(axis=1)
new_file
# Out:
#       Cреднеспис.числ.работн        k1        k2        k3        k4  \
# 0                     6095.0  0.942380  0.060563  0.678302 -0.161531
# 1                      255.0  1.980494  0.274382  0.916775  0.624425
# 2                      114.0  0.374160  0.001494  0.085138 -1.504990
# 3                      365.0  7.859079  0.831978  2.449864  0.875862
# 4                      168.0  1.779376  0.005596  0.883293  0.527853
# ...                      ...       ...       ...       ...       ...
# 2690                   217.0  2.292818  0.157246  1.344241  0.488230
# 2691                   105.0  1.572188  0.163862  1.032772  0.283944
# 2692                   121.0  1.453574  0.023380  0.692051  0.312040
# 2693                   243.0  1.310646  0.014829  0.330798  0.044386
# 2694                    98.0  3.392065  0.320780  1.399462  0.705194
#
#             k5        k6        k7        k8         k9  ...       k12  \
# ...

# %%
new_file.columns = [f'column_{i+1}' for i in range(len(new_file.columns))]
new_file
# Out:
#       column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 0       6095.0  0.942380  0.060563  0.678302 -0.161531  0.202055  0.165019
# 1        255.0  1.980494  0.274382  0.916775  0.624425  0.089377  0.220648
# 2        114.0  0.374160  0.001494  0.085138 -1.504990  0.235739  0.508929
# 3        365.0  7.859079  0.831978  2.449864  0.875862  0.059439  0.030030
# 4        168.0  1.779376  0.005596  0.883293  0.527853  0.135491  0.886686
# ...        ...       ...       ...       ...       ...       ...       ...
# 2690     217.0  2.292818  0.157246  1.344241  0.488230  0.242939  0.287504
# 2691     105.0  1.572188  0.163862  1.032772  0.283944  0.169852  0.193680
# 2692     121.0  1.453574  0.023380  0.692051  0.312040  0.191408  0.361702
# 2693     243.0  1.310646  0.014829  0.330798  0.044386  0.251739  0.151533
# 2694      98.0  3.392065  0.320780  1.399462  0.705194  0.117904  0.058603
#
# ...

# %%
new_file.plot()
# Out:
# <Axes: >

# %%
new_file[:10].plot(y=['column_2', 'column_3', 'column_4','column_5'], kind="bar")
# Out:
# <Axes: >

# %%
new_file['column_22'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
new_file.sum().plot(kind="pie", ylabel='Total clicks', fontsize=8)
# Out:
# <Axes: ylabel='Total clicks'>

# %%
new_file.plot(x="column_15", y="column_16", kind="scatter")
# Out:
# <Axes: xlabel='column_15', ylabel='column_16'>
